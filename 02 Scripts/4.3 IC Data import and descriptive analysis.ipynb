# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import data and turn project path into a string
path = r'/Users/jerrysiphavong/Desktop/12-2024 Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/jerrysiphavong/Desktop/12-2024 Instacart Basket Analysis'

# %%
# Import the 'orders.csv' data set into your notebook using the os omitting the “eval_set”

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
print(vars_list)
# Out:
# ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Print the first 5 rows of the dataframe

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Import the 'products.csv' file into Jupyter as df_prods

# %%
df_prod = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# Print the first 20 rows and the last 35 rows of the df_prods dataframe.

# %% [markdown]
# #first 20 rows

# %%
df.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %% [markdown]
# #last 35 rows

# %%
df.tail(35)
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421048    726186   206208            30          0                 16
# 3421049   2523609   206208            31          4                 11
# 3421050    756221   206208            32          6                 18
# 3421051   2254244   206208            33          6                 13
# 3421052   2017995   206208            34          6                 15
# 3421053   2789700   206208            35          3                 22
# 3421054    844592   206208            36          6                 15
# 3421055   1541132   206208            37          2                 12
# 3421056   2808240   206208            38          0                 15
# 3421057   3027766   206208            39          2                 14
# 3421058   3356245   206208            40          5                  9
# 3421059    442304   206208            41          2                 14
# ...

# %%
df_prod.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
# Print the number of rows and columns in the df_prods dataframe.

# %%
df_prod.shape
# Out:
# (49693, 5)

# %%
# What’s the maximum value of the “aisle_id” column? Answer: 134.000000

# %%
df_prod.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
# What’s the data type of the “department_id” column? Answer: Integer

# %%
df_prod.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object
